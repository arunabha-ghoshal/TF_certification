# %%
import pandas as pd
import sklearn
from matplotlib import pyplot as plt
from collections import Counter
import numpy as np
import seaborn as sns
from plotly import tools

# %%
data = pd.read_csv(r'E:\Machine Learning\Deep Learning\tf2_certification\car.data', names=['buying','maint','doors','persons','lug_boot','safety','eval'])

# %%
data.describe()
# Out:
#        buying  maint doors persons lug_boot safety   eval
# count    1728   1728  1728    1728     1728   1728   1728
# unique      4      4     4       3        3      3      4
# top     vhigh  vhigh     4       4    small   high  unacc
# freq      432    432   432     576      576    576   1210

# %%
plt.pie([int(v) for v in counts.values()],labels=[l for l in counts],autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x18554715490>,
# ...
#  [Text(-0.6472108044769336, 0.8894482416466517, 'unacc'),
#   Text(0.413550280063065, -1.0193018031278867, 'acc'),
#   Text(1.025931819423407, -0.3968172147155135, 'vgood'),
#   Text(1.0913562359976166, -0.13762836244435522, 'good')],
#  [Text(-0.35302407516923645, 0.48515358635271905, '70.0%'),
#   Text(0.22557288003439907, -0.5559828017061199, '22.2%'),
#   Text(0.5595991742309492, -0.2164457534811892, '3.8%'),
#   Text(0.5952852196350635, -0.0750700158787392, '4.0%')])

# %%
corr = data.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(data.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(data.columns)
ax.set_yticklabels(data.columns)
plt.show()

# %%
data = data.dropna()
print(data.shape)
print(list(data.columns))
data['acceptability'].value_counts()
# Out:
# (1728, 7)
# ['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'acceptability']
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: acceptability, dtype: int64

# %%
sns.countplot(x=data['acceptability'], data=data, palette='hls')
plt.show()
